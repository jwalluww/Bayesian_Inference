# %% [markdown]
# # Bayesian Regression using PYMC3

# %% [markdown]
# - https://medium.com/towards-data-science/bayesian-regression-using-pymc3-e279ccc81d20
# - https://github.com/egorhowell/Medium-Articles/blob/main/Statistics/pymc3_tutorial.ipynb

# %% [markdown]
# ## Import libraries

# %%
# Import pyMC3 and also arviz for visualisation
import pymc3 as pm
import arviz as az
# Import the other core data science packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from scipy.stats import norm
import statsmodels.formula.api as smf
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %% [markdown]
# ## Create fake data from sklearn

# %%
# Generate data
x, y = datasets.make_regression(n_samples=10_000,
                                n_features=1,
                                noise=10,
                                bias=5)
# Create the dataframe
data = pd.DataFrame(list(zip(x.flatten(), y)),columns =['x', 'y'])
# Plot the data
fig, ax = plt.subplots(figsize=(9,5))
ax.scatter(data['x'], data['y'])
ax.ticklabel_format(style='plain')
plt.xlabel('x',fontsize=18)
plt.ylabel('y',fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %%
data.head()
# Out:
#           x          y
# 0 -1.134661 -83.717024
# 1 -0.479793 -36.816412
# 2  0.295538  34.538362
# 3 -0.368850  -5.410754
# 4  0.215964  12.018548

# %% [markdown]
# ## Frequentist regression

# %%
formula = 'y ~ x'
results = smf.ols(formula, data=data).fit()
print(results.params)
print(results.resid.std())
# Out:
# Intercept     4.812229
# x            67.696636
# dtype: float64
# 9.962094794942283

# %%
# Get our equation of the OLS line
inter =  results.params['Intercept']
slope = results.params['x']
x_vals = np.arange(min(x),min(x),0.1)
ols_line = inter + slope + x_vals

# %%
# Plot the target against our feature with the OLS regression
fig, ax = plt.subplots(figsize=(9,5))
ax.scatter(data['x'], data['y'])
ax.plot(x_vals, ols_line,label='OLS Fit', color='red')
ax.ticklabel_format(style='plain')
plt.xlabel('x',fontsize=18)
plt.ylabel('y',fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.legend(fontsize=16)
plt.savefig('pic.png')
plt.show()

# %% [markdown]
# ## Baysian PYMC model

# %%
# Start our model
with pm.Model() as model:

    # Define the priors on each parameter:
    grad = pm.Uniform("grad",
                      lower=results.params['x']*0.5,
                      upper=results.params['x']*1.5)
    
    inter = pm.Uniform("inter",
                       lower=results.params['Intercept']*0.5,
                       upper=results.params['Intercept']*1.5)
    
    sigma = pm.Uniform("sigma",
                       lower=results.resid.std()*0.5,\
                       upper=results.resid.std()*1.5)
    
    # Linear regression line
    mean = inter + grad*data['x']
    
    # Describe the distribution of our conditional output
    # The normal distribution requires a mean, standard deviation (residuals), and the observed data
    y = pm.Normal('y', mu = mean, sd = sigma, observed = data['y'])

    # Run the sampling using pymc3 for 1000 samples
    trace_100 = pm.sample(100,return_inferencedata=True)
# Out:
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, inter, grad]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4400' class='' max='4400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4400/4400 00:11<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 100 draw iterations (4_000 + 400 draws total) took 36 seconds.
# WARNING (aesara.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
with model:
    az.plot_posterior(trace_100,
                      var_names=['grad', 'inter', 'sigma'],
                      textsize=18,
                      point_estimate='mean',
                      rope_color='black')

# %%
# 10x more samples
with pm.Model() as model:

    # Define the priors on each parameter:
    grad = pm.Uniform("grad",
                      lower=results.params['x']*0.5,
                      upper=results.params['x']*1.5)
    
    inter = pm.Uniform("inter",
                       lower=results.params['Intercept']*0.5,
                       upper=results.params['Intercept']*1.5)
    
    sigma = pm.Uniform("sigma",
                       lower=results.resid.std()*0.5,
                       upper=results.resid.std()*1.5)
    
    # Linear regression line
    mean = inter + grad*data['x']
    
    # Describe the distribution of our conditional output
    y = pm.Normal('y', mu = mean, sd = sigma, observed = data['y'])

    # Run the sampling using pymc3 for 10,000 samples
    trace_10_000 = pm.sample(10_000,return_inferencedata=True)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, inter, grad]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='44000' class='' max='44000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [44000/44000 00:14<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 10_000 draw iterations (4_000 + 40_000 draws total) took 29 seconds.

# %%
with model:
    az.plot_posterior(trace_10_000,
                      var_names=['grad', 'inter', 'sigma'],
                      textsize=18,
                      point_estimate='mean',
                      rope_color='black')

# %% [markdown]
# ***
# ***
# ***
