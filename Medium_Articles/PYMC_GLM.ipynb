# %% [markdown]
# # PYMC GLM

# %% [markdown]
# <br>

# %% [markdown]
# ***
# ***
# ***

# %% [markdown]
# <br>

# %% [markdown]
# # Imports

# %%
# !pip install --upgrade bambi
# Out:
# Requirement already satisfied: bambi in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (0.9.0)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from bambi) (1.4.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from bambi) (1.7.3)
# Requirement already satisfied: formulae==0.3.4 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from bambi) (0.3.4)
# Collecting pymc==4.0.0
#   Using cached pymc-4.0.0-py3-none-any.whl (554 kB)
# Requirement already satisfied: arviz>=0.11.2 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from bambi) (0.12.1)
# Requirement already satisfied: numpy<1.22.0,>=1.16.1 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from bambi) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from pymc==4.0.0->bambi) (3.10.0.2)
# Collecting aeppl==0.0.31
#   Using cached aeppl-0.0.31-py3-none-any.whl
# Requirement already satisfied: fastprogress>=0.2.0 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from pymc==4.0.0->bambi) (1.0.2)
# Collecting aesara==2.6.6
#   Using cached aesara-2.6.6-py3-none-any.whl
# Requirement already satisfied: cloudpickle in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from pymc==4.0.0->bambi) (2.1.0)
# Requirement already satisfied: cachetools>=4.2.1 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from pymc==4.0.0->bambi) (5.0.0)
# Requirement already satisfied: miniKanren in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from aesara==2.6.6->pymc==4.0.0->bambi) (1.0.3)
# Requirement already satisfied: filelock in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from aesara==2.6.6->pymc==4.0.0->bambi) (3.7.1)
# Requirement already satisfied: cons in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from aesara==2.6.6->pymc==4.0.0->bambi) (0.4.5)
# Requirement already satisfied: logical-unification in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from aesara==2.6.6->pymc==4.0.0->bambi) (0.4.5)
# Requirement already satisfied: etuples in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from aesara==2.6.6->pymc==4.0.0->bambi) (0.3.5)
# Requirement already satisfied: packaging in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from arviz>=0.11.2->bambi) (21.3)
# Requirement already satisfied: setuptools>=38.4 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from arviz>=0.11.2->bambi) (63.1.0)
# Requirement already satisfied: xarray>=0.16.1 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from arviz>=0.11.2->bambi) (2022.3.0)
# Requirement already satisfied: matplotlib>=3.0 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from arviz>=0.11.2->bambi) (3.5.2)
# Requirement already satisfied: xarray-einstats>=0.2 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from arviz>=0.11.2->bambi) (0.3.0)
# Requirement already satisfied: netcdf4 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from arviz>=0.11.2->bambi) (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from pandas>=1.0.0->bambi) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from pandas>=1.0.0->bambi) (2022.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.2->bambi) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.2->bambi) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.2->bambi) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.2->bambi) (4.34.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.2->bambi) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->bambi) (1.16.0)
# Requirement already satisfied: cftime in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from netcdf4->arviz>=0.11.2->bambi) (1.6.1)
# Requirement already satisfied: multipledispatch in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from logical-unification->aesara==2.6.6->pymc==4.0.0->bambi) (0.6.0)
# Requirement already satisfied: toolz in c:\users\a1274500\anaconda3\envs\pymc_env\lib\site-packages (from logical-unification->aesara==2.6.6->pymc==4.0.0->bambi) (0.12.0)
# Installing collected packages: aesara, aeppl, pymc
#   Attempting uninstall: aesara
#     Found existing installation: aesara 2.7.9
#     Uninstalling aesara-2.7.9:
#       Successfully uninstalled aesara-2.7.9
#   Attempting uninstall: aeppl
#     Found existing installation: aeppl 0.0.33
#     Uninstalling aeppl-0.0.33:
#       Successfully uninstalled aeppl-0.0.33
#   Attempting uninstall: pymc
#     Found existing installation: pymc 4.1.4
#     Uninstalling pymc-4.1.4:
#       Successfully uninstalled pymc-4.1.4
# Successfully installed aeppl-0.0.31 aesara-2.6.6 pymc-4.0.0

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import xarray as xr

from pymc import HalfCauchy, Model, Normal, sample

print(f"Running on PyMC v{pm.__version__}")
# Out:
# Running on PyMC v4.0.0

# %%
RANDOM_SEED = 8927
rng = np.random.default_rng(RANDOM_SEED)

# %config InlineBackend.figure_format = 'retina'
az.style.use("arviz-darkgrid")

# %% [markdown]
# # Fake Data

# %%
size = 200
true_intercept = 1
true_slope = 2

x = np.linspace(0, 1, size)
# y = a + b*x
true_regression_line = true_intercept + true_slope * x
# add noise
y = true_regression_line + rng.normal(scale=0.5, size=size)

data = pd.DataFrame(dict(x=x, y=y))

# %%
fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, xlabel="x", ylabel="y", title="Generated data and underlying model")
ax.plot(x, y, "x", label="sampled data")
ax.plot(x, true_regression_line, label="true regression line", lw=2.0)
plt.legend(loc=0);

# %% [markdown]
# # Estimating the Model

# %%
with Model() as model:  # model specifications in PyMC are wrapped in a with-statement
    # Define priors
    sigma = HalfCauchy("sigma", beta=10)
    intercept = Normal("Intercept", 0, sigma=20)
    slope = Normal("slope", 0, sigma=20)

    # Define likelihood
    likelihood = Normal("y", mu=intercept + slope * x, sigma=sigma, observed=y)

    # Inference!
    # draw 3000 posterior samples using NUTS sampling
    # idata = sample(3000)
